# %%
mysql = lambda q: sqldf(q, globals())

data_dir = '~/aiffel/sql_basic/'

bike = pd.read_csv(os.path.join(data_dir, 'bike_dataset.csv'))
orders = pd.read_csv(os.path.join(data_dir, 'orders.csv'))
customers = pd.read_csv(os.path.join(data_dir, 'customers.csv'))
employees = pd.read_csv(os.path.join(data_dir,'employees.csv'))
ds_2020 = pd.read_csv(os.path.join(data_dir, 'DS_JobsSalaries_2020.csv'))
ds_2021 = pd.read_csv(os.path.join(data_dir, 'DS_JobsSalaries_2021.csv'))

print("데이터 준비 완료!")
# Out:
# 데이터 준비 완료!

# %%
#bike 테이블에서 전체 컬럼 조회
mysql("""

SELECT *
FROM bike

""")
# Out:
#            dteday  season    yr mnth  hr  holiday   weekday  workingday  \
# 0      2011-01-01  spring  2011  Jan   0        0  Saturday           0
# 1      2011-01-01  spring  2011  Jan   1        0  Saturday           0
# 2      2011-01-01  spring  2011  Jan   2        0  Saturday           0
# 3      2011-01-01  spring  2011  Jan   3        0  Saturday           0
# 4      2011-01-01  spring  2011  Jan   4        0  Saturday           0
# ...           ...     ...   ...  ...  ..      ...       ...         ...
# 17374  2012-12-31  spring  2012  Dec  19        0    Monday           1
# 17375  2012-12-31  spring  2012  Dec  20        0    Monday           1
# 17376  2012-12-31  spring  2012  Dec  21        0    Monday           1
# 17377  2012-12-31  spring  2012  Dec  22        0    Monday           1
# 17378  2012-12-31  spring  2012  Dec  23        0    Monday           1
#
#       weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0          Clear  0.24  0.2879  0.81     0.0000       3          13   16
# 1          Clear  0.22  0.2727  0.80     0.0000       8          32   40
# 2          Clear  0.22  0.2727  0.80     0.0000       5          27   32
# 3          Clear  0.24  0.2879  0.75     0.0000       3          10   13
# 4          Clear  0.24  0.2879  0.75     0.0000       0           1    1
# ...          ...   ...     ...   ...        ...     ...         ...  ...
# 17374     Cloudy  0.26  0.2576  0.60     0.1642      11         108  119
# 17375     Cloudy  0.26  0.2576  0.60     0.1642       8          81   89
# 17376      Clear  0.26  0.2576  0.60     0.1642       7          83   90
# 17377      Clear  0.26  0.2727  0.56     0.1343      13          48   61
# 17378      Clear  0.26  0.2727  0.65     0.1343      12          37   49
#
# [17379 rows x 16 columns]

# %%
#bike 테이블에서 날짜, 계절, 날씨 컬럼 추출
mysql("""

SELECT dteday, season, weathersit
FROM bike

""")
# Out:
#            dteday  season weathersit
# 0      2011-01-01  spring      Clear
# 1      2011-01-01  spring      Clear
# 2      2011-01-01  spring      Clear
# 3      2011-01-01  spring      Clear
# 4      2011-01-01  spring      Clear
# ...           ...     ...        ...
# 17374  2012-12-31  spring     Cloudy
# 17375  2012-12-31  spring     Cloudy
# 17376  2012-12-31  spring      Clear
# 17377  2012-12-31  spring      Clear
# 17378  2012-12-31  spring      Clear
#
# [17379 rows x 3 columns]

# %%
mysql("""

SELECT *
FROM bike
WHERE yr = 2012

""")
# Out:
#           dteday  season    yr mnth  hr  holiday weekday  workingday  \
# 0     2012-01-01  spring  2012  Jan   0        0  Sunday           0
# 1     2012-01-01  spring  2012  Jan   1        0  Sunday           0
# 2     2012-01-01  spring  2012  Jan   2        0  Sunday           0
# 3     2012-01-01  spring  2012  Jan   3        0  Sunday           0
# 4     2012-01-01  spring  2012  Jan   4        0  Sunday           0
# ...          ...     ...   ...  ...  ..      ...     ...         ...
# 8729  2012-12-31  spring  2012  Dec  19        0  Monday           1
# 8730  2012-12-31  spring  2012  Dec  20        0  Monday           1
# 8731  2012-12-31  spring  2012  Dec  21        0  Monday           1
# 8732  2012-12-31  spring  2012  Dec  22        0  Monday           1
# 8733  2012-12-31  spring  2012  Dec  23        0  Monday           1
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0         Clear  0.36  0.3788  0.66     0.0000       5          43   48
# 1         Clear  0.36  0.3485  0.66     0.1343      15          78   93
# 2         Clear  0.32  0.3485  0.76     0.0000      16          59   75
# 3         Clear  0.30  0.3333  0.81     0.0000      11          41   52
# 4         Clear  0.28  0.3030  0.81     0.0896       0           8    8
# ...         ...   ...     ...   ...        ...     ...         ...  ...
# 8729     Cloudy  0.26  0.2576  0.60     0.1642      11         108  119
# 8730     Cloudy  0.26  0.2576  0.60     0.1642       8          81   89
# 8731      Clear  0.26  0.2576  0.60     0.1642       7          83   90
# 8732      Clear  0.26  0.2727  0.56     0.1343      13          48   61
# 8733      Clear  0.26  0.2727  0.65     0.1343      12          37   49
#
# [8734 rows x 16 columns]

# %%
mysql("""

SELECT dteday, season, weathersit
FROM bike
WHERE yr = 2012
LIMIT 20

""")
# Out:
#         dteday  season weathersit
# 0   2012-01-01  spring      Clear
# 1   2012-01-01  spring      Clear
# 2   2012-01-01  spring      Clear
# 3   2012-01-01  spring      Clear
# 4   2012-01-01  spring      Clear
# 5   2012-01-01  spring      Clear
# 6   2012-01-01  spring      Clear
# 7   2012-01-01  spring      Clear
# 8   2012-01-01  spring      Clear
# 9   2012-01-01  spring      Clear
# 10  2012-01-01  spring      Clear
# 11  2012-01-01  spring      Clear
# 12  2012-01-01  spring      Clear
# 13  2012-01-01  spring      Clear
# 14  2012-01-01  spring      Clear
# 15  2012-01-01  spring      Clear
# 16  2012-01-01  spring     Cloudy
# 17  2012-01-01  spring     Cloudy
# 18  2012-01-01  spring  LightRain
# 19  2012-01-01  spring  LightRain

# %%
mysql("""

SELECT *
FROM bike
WHERE season != 'spring'

""")
# Out:
#            dteday  season    yr mnth  hr  holiday   weekday  workingday  \
# 0      2011-03-21  summer  2011  Mar   0        0    Monday           1
# 1      2011-03-21  summer  2011  Mar   1        0    Monday           1
# 2      2011-03-21  summer  2011  Mar   2        0    Monday           1
# 3      2011-03-21  summer  2011  Mar   3        0    Monday           1
# 4      2011-03-21  summer  2011  Mar   5        0    Monday           1
# ...           ...     ...   ...  ...  ..      ...       ...         ...
# 13132  2012-12-20  winter  2012  Dec  19        0  Thursday           1
# 13133  2012-12-20  winter  2012  Dec  20        0  Thursday           1
# 13134  2012-12-20  winter  2012  Dec  21        0  Thursday           1
# 13135  2012-12-20  winter  2012  Dec  22        0  Thursday           1
# 13136  2012-12-20  winter  2012  Dec  23        0  Thursday           1
#
#       weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 
rows x 16 columns]

# %%
mysql("""

SELECT *
FROM bike
WHERE weathersit is NULL

""")
# Out:
#        dteday  season    yr mnth  hr  holiday   weekday  workingday  \
# 0  2011-02-19  spring  2011  Feb  11        0  Saturday           0
#
#   weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0       None  0.44  0.4394  0.16     0.5821      47          76  123

# %%
mysql("""

SELECT *
FROM bike
WHERE weathersit IS NOT NULL

""")
# Out:
#            dteday  season    yr mnth  hr  holiday   weekday  workingday  \
# 0      2011-01-01  spring  2011  Jan   0        0  Saturday           0
# 1      2011-01-01  spring  2011  Jan   1        0  Saturday           0
# 2      2011-01-01  spring  2011  Jan   2        0  Saturday           0
# 3      2011-01-01  spring  2011  Jan   3        0  Saturday           0
# 4      2011-01-01  spring  2011  Jan   4        0  Saturday           0
# ...           ...     ...   ...  ...  ..      ...       ...         ...
# 17373  2012-12-31  spring  2012  Dec  19        0    Monday           1
# 17374  2012-12-31  spring  2012  Dec  20        0    Monday           1
# 17375  2012-12-31  spring  2012  Dec  21        0    Monday           1
# 17376  2012-12-31  spring  2012  Dec  22        0    Monday           1
# 17377  2012-12-31  spring  2012  Dec  23        0    Monday           1
#
#       weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0          Clear  0.24  0.2879  0.81     0.0000       3          13   16
# 1          Clear  0.22  0.2727  0.80     0.0000       8          32   40
# 2          Clear  0.22  0.2727  0.80     0.0000       5          27   32
# 3          Clear  0.24  0.2879  0.75     0.0000       3          10   13
# 4          Clear  0.24  0.2879  0.75     0.0000       0           1    1
# ...          ...   ...     ...   ...        ...     ...         ...  ...
# 17373     Cloudy  0.26  0.2576  0.60     0.1642      11         108  119
# 17374     Cloudy  0.26  0.2576  0.60     0.1642       8          81   89
# 17375      Clear  0.26  0.2576  0.60     0.1642       7          83   90
# 17376      Clear  0.26  0.2727  0.56     0.1343      13          48   61
# 17377      Clear  0.26  0.2727  0.65     0.1343      12          37   49
#
# [17378 rows x 16 columns]

# %%
mysql("""

SELECT *
FROM bike
WHERE mnth NOT IN('Jan', 'Mar', 'May')
AND yr = 2011

""")
# Out:
#           dteday  season    yr mnth  hr  holiday   weekday  workingday  \
# 0     2011-02-01  spring  2011  Feb   0        0   Tuesday           1
# 1     2011-02-01  spring  2011  Feb   1        0   Tuesday           1
# 2     2011-02-01  spring  2011  Feb   2        0   Tuesday           1
# 3     2011-02-01  spring  2011  Feb   3        0   Tuesday           1
# 4     2011-02-01  spring  2011  Feb   5        0   Tuesday           1
# ...          ...     ...   ...  ...  ..      ...       ...         ...
# 6478  2011-12-31  spring  2011  Dec  19        0  Saturday           0
# 6479  2011-12-31  spring  2011  Dec  20        0  Saturday           0
# 6480  2011-12-31  spring  2011  Dec  21        0  Saturday           0
# 6481  2011-12-31  spring  2011  Dec  22        0  Saturday           0
# 6482  2011-12-31  spring  2011  Dec  23        0  Saturday           0
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0        Cloudy  0.16  0.1818  0.64     0.1045       2           6    8
# 1        Cloudy  0.16  0.1818  0.69     0.1045       0           3    3
# 2        Cloudy  0.16  0.2273  0.69     0.0000       0           2    2
# 3        Cloudy  0.16  0.2273  0.69     0.0000       0           2    2
# 4     LightRain  0.14  0.2121  0.93     0.0000       0           3    3
# ...         ...   ...     ...   ...        ...     ...         ...  ...
# 6478      Clear  0.42  0.4242  0.54     0.2239      19          73   92
# 6479      Clear  0.42  0.4242  0.54     0.2239       8          63   71
# 6480      Clear  0.40  0.4091  0.58     0.1940       2          50   52
# 6481      Clear  0.38  0.3939  0.62     0.1343       2          36   38
# 6482      Clear  0.36  0.3788  0.66     0.0000       4          27   31
#
# [6483 rows x 16 columns]

# %%
mysql("""

SELECT *
FROM bike
WHER
# 15  LightRain  0.28  0.2576  0.81     0.2985      14          56   70
# 16  LightRain  0.28  0.2727  0.87     0.2537       0          36   36
# 17  LightRain  0.26  0.2727  0.93     0.1045      11         105  116
# 18     Cloudy  0.26  0.2576  0.93     0.2239       6          79   85
# 19     Cloudy  0.26  0.2576  0.93     0.2239       5          67   72
# 20  LightRain  0.24  0.2121  0.93     0.2985       4          40   44
# 21     Cloudy  0.24  0.2273  0.93     0.2537       0          27   27
# 22  LightRain  0.24  0.2273  0.93     0.2239       3          21   24
# 23  LightRain  0.24  0.2121  0.93     0.2836       1          11   12
# 24  LightRain  0.24  0.2273  0.93     0.2239       0           3    3
# 25  LightRain  0.24  0.2273  0.93     0.1940       1           4    5
# 26  LightRain  0.24  0.2273  0.93     0.1940       0           5    5
# 27  LightRain  0.24  0.2273  0.93     0.2239       0           1    1
# 28  LightRain  0.24  0.2273  0.93     0.2537       0           2    2
# 29  LightRain  0.24  0.2273  0.93     0.2239       0           8    8
# 30  LightRain  0.24  0.2121  0.93     0.2985       2          34   36
# 31  LightRain  0.24  0.2273  0.93     0.2537       5          87   92
# 32     Cloudy  0.24  0.2273  1.00     0.2537       7         185  192
# 33  LightRain  0.26  0.2424  0.93     0.2537       6         126  132
# 34  LightRain  0.26  0.2424  0.93     0.2537      15          54   69
# 35  LightRain  0.28  0.2727  0.93     0.1940       6          52   58
# 36  LightRain  0.28  0.2727  0.93     0.1940      17          73   90
# 37  LightRain  0.30  0.3030  0.87     0.1343      13          55   68
# 38  LightRain  0.30  0.3030  0.87     0.1343      27          49   76
# 39  LightRain  0.30  0.2727  0.87     0.2985       4          61   65
# 40     Cloudy  0.30  0.2879  0.87     0.2537      13          72   85
# 41     Cloudy  0.30  0.2879  0.87     0.2537      15         153  168
# 42     Cloudy  0.30  0.3030  0.87     0.1343      12         165  177
# 43     Cloudy  0.30  0.3030  0.87     0.1343      12         118  130
# 44  LightRain  0.28  0.2576  0.93     0.2836       6          79   85
# 45     Cloudy  0.28  0.2727  0.93     0.1642       7          53   60
# 46  LightRain  0.28  0.2727  0.93     0.2537       7          44   51
# 47  LightRain  0.26  0.2576  1.00     0.1642       4          23   27

# %%
mysql("""

SELECT temp
    , temp + 2
    , temp - 2
    , temp * 2
    , temp / 2
FROM bike

""")
# Out:
#        temp  temp + 2  temp - 2  temp * 2  temp / 2
# 0      0.24      2.24     -1.76      0.48      0.12
# 1      0.22      2.22     -1.78      0.44      0.11
# 2      0.22      2.22     -1.78      0.44      0.11
# 3      0.24      2.24     -1.76      0.48      0.12
# 4      0.24      2.24     -1.76      0.48      0.12
# ...     ...       ...       ...       ...       ...
# 17374  0.26      2.26     -1.74      0.52      0.13
# 17375  0.26      2.26     -1.74      0.52      0.13
# 17376  0.26      2.26     -1.74      0.52      0.13
# 17377  0.26      2.26     -1.74      0.52      0.13
# 17378  0.26      2.26     -1.74      0.52      0.13
#
# [17379 rows x 5 columns]

# %%
import os
import pandas as pd 
from pandasql import sqldf
mysql = lambda q: sqldf(q, globals())

data_dir = '~/aiffel/sql_basic/'

bike = pd.read_csv(os.path.join(data_dir, 'bike_dataset.csv'))
orders = pd.read_csv(os.path.join(data_dir, 'orders.csv'))
customers = pd.read_csv(os.path.join(data_dir, 'customers.csv'))
employees = pd.read_csv(os.path.join(data_dir,'employees.csv'))
ds_2020 = pd.read_csv(os.path.join(data_dir, 'DS_JobsSalaries_2020.csv'))
ds_2021 = pd.read_csv(os.path.join(data_dir, 'DS_JobsSalaries_2021.csv'))

print("데이터 준비 완료!")
# Out:
# 데이터 준비 완료!

# %%
mysql("""

SELECT *
FROM bike
WHERE hr = 0
AND weekday LIKE '%ur%'

""")
# Out:
#          dteday  season    yr mnth  hr  holiday   weekday  workingday  \
# 0    2011-01-01  spring  2011  Jan   0        0  Saturday           0
# 1    2011-01-06  spring  2011  Jan   0        0  Thursday           1
# 2    2011-01-08  spring  2011  Jan   0        0  Saturday           0
# 3    2011-01-13  spring  2011  Jan   0        0  Thursday           1
# 4    2011-01-15  spring  2011  Jan   0        0  Saturday           0
# ..          ...     ...   ...  ...  ..      ...       ...         ...
# 203  2012-12-15  winter  2012  Dec   0        0  Saturday           0
# 204  2012-12-20  winter  2012  Dec   0        0  Thursday           1
# 205  2012-12-22  spring  2012  Dec   0        0  Saturday           0
# 206  2012-12-27  spring  2012  Dec   0        0  Thursday           1
# 207  2012-12-29  spring  2012  Dec   0        0  Saturday           0
#
#     weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0        Clear  0.24  0.2879  0.81     0.0000       3          13   16
# 1        Clear  0.18  0.2424  0.55     0.0000       0          11   11
# 2       Cloudy  0.18  0.1970  0.51     0.1642       1          24   25
# 3        Clear  0.14  0.1212  0.59     0.2836       1           6    7
# 4        Clear  0.18  0.2424  0.55     0.0000       3          25   28
# ..         ...   ...     ...   ...        ...     ...         ...  ...
# 203      Clear  0.30  0.3333  0.70     0.0000       4          90   94
# 204      Clear  0.32  0.3333  0.61     0.1343       2          40   42
# 205      Clear  0.26  0.2121  0.44     0.5821       1          30   31
# 206  LightRain  0.26  0.2273  0.87     0.2985       0           3    3
# 207     Cloudy  0.24  0.2424  0.70     0.0000       1          25   26
#
# [208 rows x 16 columns]

# %%
mysql("""

SELECT *
FROM bike
WHERE hr = 0
AND weathersit LIKE 'Cl%'

""")
# Out:
#          dteday  season    yr mnth  hr  holiday    weekday  workingday  \
# 0    2011-01-01  spring  2011  Jan   0        0   Saturday           0
# 1    2011-01-02  spring  2011  Jan   0        0     Sunday           0
# 2    2011-01-03  spring  2011  Jan   0        0     Monday           1
# 3    2011-01-04  spring  2011  Jan   0        0    Tuesday           1
# 4    2011-01-05  spring  2011  Jan   0        0  Wednesday           1
# ..          ...     ...   ...  ...  ..      ...        ...         ...
# 669  2012-12-26  spring  2012  Dec   0        0  Wednesday           1
# 670  2012-12-28  spring  2012  Dec   0        0     Friday           1
# 671  2012-12-29  spring  2012  Dec   0        0   Saturday           0
# 672  2012-12-30  spring  2012  Dec   0        0     Sunday           0
# 673  2012-12-31  spring  2012  Dec   0        0     Monday           1
#
#     weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0        Clear  0.24  0.2879  0.81     0.0000       3          13   16
# 1       Cloudy  0.46  0.4545  0.88     0.2985       4          13   17
# 2        Clear  0.22  0.1970  0.44     0.3582       0           5    5
# 3        Clear  0.16  0.1818  0.55     0.1045       0           5    5
# 4        Clear  0.20  0.2576  0.64     0.0000       0           6    6
# ..         ...   ...     ...   ...        ...     ...         ...  ...
# 669     Cloudy  0.28  0.2727  0.65     0.2537       1           8    9
# 670     Cloudy  0.24  0.2424  0.60     0.1642       3          22   25
# 671     Cloudy  0.24  0.2424  0.70     0.0000       1          25   26
# 672     Cloudy  0.26  0.2576  0.60     0.1642       0          41   41
# 673      Clear  0.18  0.1818  0.55     0.1940       4          30   34
#
# [674 rows x 16 columns]

# %%
mysql("""

SELECT *
FROM bike
WHERE hr = 0
AND mnth LIKE 'ma?_'

""")

# %%
mysql("""

SELECT b.temp, b.hum AS 'humidity'
FROM bike AS b
LIMIT 5

""")
# Out:
#    temp  humidity
# 0  0.24      0.81
# 1  0.22      0.80
# 2  0.22      0.80
# 3  0.24      0.75
# 4  0.24      0.75

# %%
mysql("""

SELECT dteday, temp, cnt
FROM bike
ORDER BY cnt DESC, temp
LIMIT 100

""")
# Out:
#         dteday  temp  cnt
# 0   2012-09-12  0.66  977
# 1   2012-09-20  0.64  976
# 2   2012-09-11  0.70  970
# 3   2012-09-10  0.62  968
# 4   2012-09-25  0.66  967
# ..         ...   ...  ...
# 95  2012-06-11  0.80  831
# 96  2012-03-23  0.70  830
# 97  2012-07-11  0.80  830
# 98  2012-10-11  0.50  827
# 99  2012-05-31  0.76  827
#
# [100 rows x 3 columns]

# %%
mysql("""

SELECT dteday, temp, cnt
FROM bike
ORDER BY 3 DESC, 2
LIMIT 100

""")
# Out:
#         dteday  temp  cnt
# 0   2012-09-12  0.66  977
# 1   2012-09-20  0.64  976
# 2   2012-09-11  0.70  970
# 3   2012-09-10  0.62  968
# 4   2012-09-25  0.66  967
# ..         ...   ...  ...
# 95  2012-06-11  0.80  831
# 96  2012-03-23  0.70  830
# 97  2012-07-11  0.80  830
# 98  2012-10-11  0.50  827
# 99  2012-05-31  0.76  827
#
# [100 rows x 3 columns]

# %%
mysql("""

SELECT DISTINCT weekday, weathersit
FROM bike

""")
# Out:
#       weekday         weathersit
# 0    Saturday              Clear
# 1    Saturday             Cloudy
# 2    Saturday          LightRain
# 3      Sunday             Cloudy
# 4      Sunday          LightRain
# 5      Sunday              Clear
# 6      Monday              Clear
# 7     Tuesday              Clear
# 8     Tuesday             Cloudy
# 9   Wednesday              Clear
# 10   Thursday              Clear
# 11   Thursday             Cloudy
# 12     Friday             Cloudy
# 13     Friday          LightRain
# 14     Friday              Clear
# 15     Monday             Cloudy
# 16    Tuesday          LightRain
# 17  Wednesday             Cloudy
# 18     Monday          LightRain
# 19  Wednesday          LightRain
# 20  Wednesday  Snow_Thunderstorm
# 21   Thursday          LightRain
# 22   Saturday               None
# 23     Monday  Snow_Thunderstorm
# 24   Saturday  Snow_Thunderstorm

# %%
mysql("""

SELECT DISTINCT yr, weekday, weathersit
FROM bike

""")
# Out:
#       yr    weekday         weathersit
# 0   2011   Saturday              Clear
# 1   2011   Saturday             Cloudy
# 2   2011   Saturday          LightRain
# 3   2011     Sunday             Cloudy
# 4   2011     Sunday          LightRain
# 5   2011     Sunday              Clear
# 6   2011     Monday              Clear
# 7   2011    Tuesday              Clear
# 8   2011    Tuesday             Cloudy
# 9   2011  Wednesday              Clear
# 10  2011   Thursday              Clear
# 11  2011   Thursday             Cloudy
# 12  2011     Friday             Cloudy
# 13  2011     Friday          LightRain
# 14  2011     Friday              Clear
# 15  2011     Monday             Cloudy
# 16  2011    Tuesday          LightRain
# 17  2011  Wednesday             Cloudy
# 18  2011     Monday          LightRain
# 19  2011  Wednesday          LightRain
# 20  2011  Wednesday  Snow_Thunderstorm
# 21  2011   Thursday          LightRain
# 22  2011   Saturday               None
# 23  2012     Sunday              Clear
# 24  2012     Sunday             Cloudy
# 25  2012     Sunday          LightRain
# 26  2012     Monday              Clear
# 27  2012     Monday             Cloudy
# 28  2012    Tuesday              Clear
# 29  2012  Wednesday              Clear
# 30  2012  Wednesday             Cloudy
# 31  2012   Thursday             Cloudy
# 32  2012   Thursday              Clear
# 33  2012     Friday              Clear
# 34  2012     Friday             Cloudy
# 35  2012   Saturday              Clear
# 36  2012   Saturday             Cloudy
# 37  2012     Monday          LightRain
# 38  2012     Monday  Snow_Thunderstorm
# 39  2012    Tuesday             Cloudy
# 40  2012  Wednesday          LightRain
# 41  2012   Thursday          LightRain
# 42  2012     Friday          LightRain
# 43  2012    Tuesday          LightRain
# 44  2012   Saturday          LightRain
# 45  2012   Saturday  Snow_Thunderstorm

# %%
mysql("""

SELECT customerName AS "고객명"
    , birthday AS "생년월일"
    , iif(birthday >= '1990-01-01', '90년 이후', '90년 이전') AS "1990년 기준"
FROM customers

""")
# Out:
#                         고객명          생년월일 1990년 기준
# 0             Unai Bustinza    1992. 2. 2   90년 이후
# 1              Igor Bubnjic   1992. 7. 17   90년 이후
# 2               Gideon Jung   1994. 9. 12   90년 이후
# 3          Alberto Aquilani    1984. 7. 7   90년 이전
# 4         Nicola Strambelli    1988. 9. 6   90년 이전
# ..                      ...           ...      ...
# 118     Jeroen Vanthournout   1989. 6. 29   90년 이전
# 119            Raul Rusescu    1988. 7. 9   90년 이전
# 120  Konstantinos Fortounis  1992. 10. 16   90년 이후
# 121                    Sami  1988. 12. 18   90년 이전
# 122         Szymon Drewniak   1993. 7. 11   90년 이후
#
# [123 rows x 3 columns]

# %%
mysql("""

SELECT customerName, creditLimit
    , CASE WHEN creditLimit <= 5 THEN '5만원 이하'
            WHEN creditLimit <= 10 THEN '10만원 이하'
            ELSE '10만원 초과'
    END AS '고객한도분리'
FROM customers

""")
# Out:
#                customerName  creditLimit   고객한도분리
# 0             Unai Bustinza        21000  10만원 초과
# 1              Igor Bubnjic        71800  10만원 초과
# 2               Gideon Jung       117300  10만원 초과
# 3          Alberto Aquilani       118200  10만원 초과
# 4         Nicola Strambelli        81700  10만원 초과
# ..                      ...          ...      ...
# 118     Jeroen Vanthournout        60300  10만원 초과
# 119            Raul Rusescu        43300  10만원 초과
# 120  Konstantinos Fortounis        85100  10만원 초과
# 121                    Sami       110000  10만원 초과
# 122         Szymon Drewniak        88900  10만원 초과
#
# [123 rows x 3 columns]

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dteday      17379 non-null  object
#  1   season      17379 non-null  object
#  2   yr          17379 non-null  int64
#  3   mnth        17379 non-null  object
#  4   hr          17379 non-null  int64
#  5   holiday     17379 non-null  int64
#  6   weekday     17379 non-null  object
#  7   workingday  17379 non-null  int64
#  8   weathersit  17378 non-null  object
#  9   temp        17379 non-null  float64
#  10  atemp       17379 non-null  float64
#  11  hum         17379 non-null  float64
#  12  windspeed   17379 non-null  float64
#  13  casual      17379 non-null  int64
#  14  registered  17379 non-null  int64
#  15  cnt         17379 non-null  int64
# dtypes: float64(4), int64(7), object(5)
# memory usage: 2.1+ MB

# %%
mysql("""

SELECT *
FROM bike
WHERE yr = 2011
LIMIT 5

""")
# Out:
#        dteday  season    yr mnth  hr  holiday   weekday  workingday  \
# 0  2011-01-01  spring  2011  Jan   0        0  Saturday           0
# 1  2011-01-01  spring  2011  Jan   1        0  Saturday           0
# 2  2011-01-01  spring  2011  Jan   2        0  Saturday           0
# 3  2011-01-01  spring  2011  Jan   3        0  Saturday           0
# 4  2011-01-01  spring  2011  Jan   4        0  Saturday           0
#
#   weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0      Clear  0.24  0.2879  0.81        0.0       3          13   16
# 1      Clear  0.22  0.2727  0.80        0.0       8          32   40
# 2      Clear  0.22  0.2727  0.80        0.0       5          27   32
# 3      Clear  0.24  0.2879  0.75        0.0       3          10   13
# 4      Clear  0.24  0.2879  0.75        0.0       0           1    1

# %%
mysql("""

SELECT CAST(yr AS varchar) AS yr
FROM bike
LIMIT 5

""")
# Out:
#      yr
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   employeesId  5 non-null      int64
#  1   name         5 non-null      object
#  2   jobTitle     5 non-null      object
#  3   level        5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 288.0+ bytes

# %%
mysql("""

SELECT *
FROM customers

""")
# Out:
#    customer_id customer_name city                 signup_date
# 0          101           김철수   서울  2023-03-15 00:00:00.000000
# 1          102           박영희   부산  2023-08-20 00:00:00.000000
# 2          103           이민준   서울  2024-01-10 00:00:00.000000
# 3          104           최지우   인천  2024-05-25 00:00:00.000000
# 4          105           김민지   대구  2023-11-30 00:00:00.000000
# 5          106           정성훈   부산  2024-02-18 00:00:00.000000

# %%
import pandas as pd

# 'Products' 데이터프레임 생성
products_data = {
    'product_id': [1, 2, 3, 4, 5, 6, 7],
    'product_name': ['스마트 OLED TV', '게이밍 노트북', '스마트 냉장고', '블루투스 키보드', '스마트 워치', '공기청정기', '무선 마우스'],
    'category': ['가전', '전자제품', '가전', '액세서리', '액세서리', '가전', '액세서리'],
    'price': [1500000, 1200000, 950000, 85000, 280000, 450000, 40000]
}
products = pd.DataFrame(products_data)

# 'Customers' 데이터프레임 생성
customers_data = {
    'customer_id': [101, 102, 103, 104, 105, 106],
    'customer_name': ['김철수', '박영희', '이민준', '최지우', '김민지', '정성훈'],
    'city': ['서울', '부산', '서울', '인천', '대구', '부산'],
    'signup_date': ['2023-03-15', '2023-08-20', '2024-01-10', '2024-05-25', '2023-11-30', '2024-02-18']
}
customers = pd.DataFrame(customers_data)

# 날짜 컬럼을 datetime 형식으로 변환 (더 효율적인 데이터 처리를 위해 권장)
customers['signup_date'] = pd.to_datetime(customers['signup_date'])

# %%
mysql("""

SELECT *
FROM Products

""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899                 if not evt_handled:
# -> 1900                     self.dialect.do_execute(
#    1901                         cursor, statement, parameters, context
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# OperationalError: no such table: Products
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/pandasql/sqldf.py in __call__(self, query, env)
#      60             try:
# ---> 61                 result = read_sql(query, conn)
#      62             except DatabaseError as ex:
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     627     else:
# --> 628         return pandas_sql.read_query(
#     629             sql,
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1578
# -> 1579         result = self.execute(*args)
#    1580         columns = result.keys()
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1423         """Simple passthrough to SQLAlchemy connectable"""
# -> 1424         return self.connectable.execution_options().execute(*args, **kwargs)
#    1425
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1364
# -> 1365             return self._exec_driver_sql(
#    1366                 statement,
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1668         dialect = self.dialect
# -> 1669         ret = self._execute_context(
#    1670             dialect,
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1942         except BaseException as e:
# -> 1943             self._handle_dbapi_exception(
#    1944                 e, statement, parameters, cursor, context
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2123             elif should_wrap:
# -> 2124                 util.raise_(
#    2125                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     207         try:
# --> 208             raise exception
#     209         finally:
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899                 if not evt_handled:
# -> 1900                     self.dialect.do_execute(
#    1901                         cursor, statement, parameters, context
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# OperationalError: (sqlite3.OperationalError) no such table: Products
# [SQL:
#
# SELECT *
# FROM Products
#
# ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# PandaSQLException                         Traceback (most recent call last)
# /tmp/ipykernel_34/1129963801.py in <module>
# ----> 1 mysql("""
#       2
#       3 SELECT *
#       4 FROM Products
#       5
#
# /tmp/ipykernel_34/2106267606.py in <lambda>(q)
#       2 import pandas as pd
#       3 from pandasql import sqldf
# ----> 4 mysql = lambda q: sqldf(q, globals())
#       5
#       6 data_dir = '~/aiffel/sql_basic/'
#
# /opt/conda/lib/python3.9/site-packages/pandasql/sqldf.py in sqldf(query, env, db_uri)
#     154     >>> sqldf("select avg(x) from df;", locals())
#     155     """
# --> 156     return PandaSQL(db_uri)(query, env)
#
# /opt/conda/lib/python3.9/site-packages/pandasql/sqldf.py in __call__(self, query, env)
#      61                 result = read_sql(query, conn)
#      62             except DatabaseError as ex:
# ---> 63                 raise PandaSQLException(ex)
#      64             except ResourceClosedError:
#      65                 # query returns nothing
#
# PandaSQLException: (sqlite3.OperationalError) no such table: Products
# [SQL:
#
# SELECT *
# FROM Products
#
# ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
