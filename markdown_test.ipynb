# %% [markdown]
# # This is a H1
# ## This is a H2
# ### This is a H3
# #### This is a H4
# ##### This is a H5
# ###### This is a H6
#
# ---
#
# 1. 첫번째
# 2. 두번째
# 3. 세번째
#
# ---
#
# - 빨강
#     - 빨강
#         - 빨강
#
# * 파랑
#     * 파랑
#         * 파랑
#
# + 노랑
#     + 노랑
#         + 노랑
# ---
# 혼합해서 사용하는 것도 가능
#
# * 1단계
#     - 2단계
#         + 3단계
#             + 4단계
#
# ---
#
# > This is a first blockquote.
# >   > This is a second blockquote.
# >   >   > This is a third blockquote.
#
# ---
#
# 링크는 [보여줄 이름](https://~link~..)의 형태로 나타낼 수 있다.
#
# [Google](https://google.com)
#
# 오. 하이퍼링크 이동도 잘 된다.
#
# ---
# *single asterisks*
#
# _single underscores_
#
# **double asterisks**
#
# __double underscores__
#
# ~~cancelline~~
#
# ---
#
# 코드블럭 입히기
#
# ```
# print("hello Markdown")
# ```
#
#
# ---
#
# 줄바꿈을 위해서는 엔터 2번!!
#
# ## 엔터 1번 쳤을 때
# 줄바꿈을 하기 위해서는 문장 마지막에서 2칸 이상을 띄어쓰기해야 한다.
# 이렇게
#
# ## 엔터 2번 쳤을 때
# 줄바꿈을 하기 위해서는 문장 마지막에서 2칸 이상을 띄어쓰기해야 한다.
#
# 이렇게
#
# ---
#
# 참조링크
#
# [모두의 연구소](https://lms.aiffel.io/course/1648/node/1074/step/6669)
#
# * 모두의 연구소 : <https://lms.aiffel.io/course/1648/node/1074/step/6669>
#
# * 네이버 : <www.naver.com>
#
#
# ---
#
# 마크다운(Markdown)은 일반 텍스트 기반의 경량 마크업 언어이다. 일반 텍스트로 서식이 있는 문서를 작성하는 데 사용되며, 일반 마크업 언어에 비해 문법이 쉽고 간단한 것이 특징이다. (출처: [위키피디아](https://ko.wikipedia.org/wiki/%EB%A7%88%ED%81%AC%EB%8B%A4%EC%9A%B4))
#
# * [마크다운 공식 사이트](https://daringfireball.net/projects/markdown/)
# * [GitHub](https://github.com/)
# * [아이펠](https://aiffel.io/)
#
#
# * __[마크다운 공식 사이트]__(https://daringfireball.net/projects/markdown/)
# * ___[GitHub]___(https://github.com/)
# * *[아이펠]*(https://aiffel.io/)
#
# ---
#
# 이번엔 사진이다.
#
# ![오리 사진이다](https://d3s0tskafalll9.cloudfront.net/media/images/F-3-23.max-800x600_yafLaWc.png)
#
# <imge src="/path/to/img.jpg" width="120px" height="80px"><img>
#
#
# ![이번엔 고양이다](img.png)
